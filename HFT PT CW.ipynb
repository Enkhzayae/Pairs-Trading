# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download(tickers='BTC-USD',start = '2022-12-21', end='2022-12-22', interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                              Open          High           Low         Close  \
# Datetime
# 2022-12-21 00:00:00  16904.527344  16904.527344  16904.527344  16904.527344
# 2022-12-21 00:01:00  16903.636719  16903.636719  16903.636719  16903.636719
# 2022-12-21 00:02:00  16902.189453  16902.189453  16902.189453  16902.189453
# 2022-12-21 00:03:00  16902.644531  16902.644531  16902.644531  16902.644531
# 2022-12-21 00:04:00  16905.384766  16905.384766  16905.384766  16905.384766
# ...                           ...           ...           ...           ...
# 2022-12-21 23:54:00  16810.763672  16810.763672  16810.763672  16810.763672
# 2022-12-21 23:55:00  16810.142578  16810.142578  16810.142578  16810.142578
# 2022-12-21 23:56:00  16809.978516  16809.978516  16809.978516  16809.978516
# 2022-12-21 23:57:00  16812.873047  16812.873047  16812.873047  16812.873047
# 2022-12-21 23:58:00  16816.419922  16816.419922  16816.419922  16816.419922
#
#                         Adj Close    Volume
# Datetime
# 2022-12-21 00:00:00  16904.527344         0
# 2022-12-21 00:01:00  16903.636719         0
# 2022-12-21 00:02:00  16902.189453         0
# 2022-12-21 00:03:00  16902.644531         0
# 2022-12-21 00:04:00  16905.384766         0
# ...                           ...       ...
# 2022-12-21 23:54:00  16810.763672         0
# 2022-12-21 23:55:00  16810.142578         0
# 2022-12-21 23:56:00  16809.978516         0
# 2022-12-21 23:57:00  16812.873047   3271680
# 2022-12-21 23:58:00  16816.419922  11825152
#
# [1432 rows x 6 columns]

# %%
ETH = yf.download(tickers='ETH-USD',start = '2022-12-21', end='2022-12-22', interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                             Open         High          Low        Close  \
# Datetime
# 2022-12-21 00:00:00  1217.586426  1217.586426  1217.586426  1217.586426
# 2022-12-21 00:01:00  1217.319458  1217.319458  1217.319458  1217.319458
# 2022-12-21 00:02:00  1217.234131  1217.234131  1217.234131  1217.234131
# 2022-12-21 00:03:00  1217.251831  1217.251831  1217.251831  1217.251831
# 2022-12-21 00:04:00  1217.346069  1217.346069  1217.346069  1217.346069
# ...                          ...          ...          ...          ...
# 2022-12-21 23:54:00  1212.758423  1212.758423  1212.758423  1212.758423
# 2022-12-21 23:55:00  1212.607056  1212.607056  1212.607056  1212.607056
# 2022-12-21 23:56:00  1212.667236  1212.667236  1212.667236  1212.667236
# 2022-12-21 23:57:00  1213.098022  1213.098022  1213.098022  1213.098022
# 2022-12-21 23:58:00  1213.545532  1213.545532  1213.545532  1213.545532
#
#                        Adj Close   Volume
# Datetime
# 2022-12-21 00:00:00  1217.586426        0
# 2022-12-21 00:01:00  1217.319458        0
# 2022-12-21 00:02:00  1217.234131        0
# 2022-12-21 00:03:00  1217.251831        0
# 2022-12-21 00:04:00  1217.346069        0
# ...                          ...      ...
# 2022-12-21 23:54:00  1212.758423        0
# 2022-12-21 23:55:00  1212.607056        0
# 2022-12-21 23:56:00  1212.667236        0
# 2022-12-21 23:57:00  1213.098022  1226496
# 2022-12-21 23:58:00  1213.545532  2409984
#
# [1432 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 16904.52734375

# %%
S2_0
# Out:
# 1217.58642578125

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1432
mu_2 = lr2.mean() * 1432
sigma_1 = lr1.std() * np.sqrt(1432)
sigma_2 = lr2.std() * np.sqrt(1432)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.3
delta = 1
T = 1
M = len(BTC)

# %%
rho
# Out:
# 0.8674158730287858

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
beta
# Out:
# 0.7265476627696168

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Bitcoin')
plt.plot(tt, S2, 'r', lw=1.5, label='Ethereum')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Crypto Price')
# Out:
# Text(0.5, 1.0, 'Crypto Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Bitcoin')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Bitcoin Price')
# Out:
# Text(0.5, 1.0, 'Bitcoin Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S2, 'r', lw=1.5, label='Ethereum')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Ethereum Price')
# Out:
# Text(0.5, 1.0, 'Ethereum Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([971.27232546])

# %%
Wealth[-1]
# Out:
# array([1643.81696904])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([0.69243674])

# %%
Pi_1.mean()
# Out:
# -0.032132728102065786

# %%
Pi_2.mean()
# Out:
# 0.7866736735054629

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download(tickers='BTC-USD',start = '2022-12-21', end='2022-12-22', interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                              Open          High           Low         Close  \
# Datetime
# 2022-12-21 00:00:00  16904.527344  16904.527344  16904.527344  16904.527344
# 2022-12-21 00:01:00  16903.636719  16903.636719  16903.636719  16903.636719
# 2022-12-21 00:02:00  16902.189453  16902.189453  16902.189453  16902.189453
# 2022-12-21 00:03:00  16902.644531  16902.644531  16902.644531  16902.644531
# 2022-12-21 00:04:00  16905.384766  16905.384766  16905.384766  16905.384766
# ...                           ...           ...           ...           ...
# 2022-12-21 23:54:00  16810.763672  16810.763672  16810.763672  16810.763672
# 2022-12-21 23:55:00  16810.142578  16810.142578  16810.142578  16810.142578
# 2022-12-21 23:56:00  16809.978516  16809.978516  16809.978516  16809.978516
# 2022-12-21 23:57:00  16812.873047  16812.873047  16812.873047  16812.873047
# 2022-12-21 23:58:00  16816.419922  16816.419922  16816.419922  16816.419922
#
#                         Adj Close    Volume
# Datetime
# 2022-12-21 00:00:00  16904.527344         0
# 2022-12-21 00:01:00  16903.636719         0
# 2022-12-21 00:02:00  16902.189453         0
# 2022-12-21 00:03:00  16902.644531         0
# 2022-12-21 00:04:00  16905.384766         0
# ...                           ...       ...
# 2022-12-21 23:54:00  16810.763672         0
# 2022-12-21 23:55:00  16810.142578         0
# 2022-12-21 23:56:00  16809.978516         0
# 2022-12-21 23:57:00  16812.873047   3271680
# 2022-12-21 23:58:00  16816.419922  11825152
#
# [1432 rows x 6 columns]

# %%
ETH = yf.download(tickers='ETH-USD',start = '2022-12-21', end='2022-12-22', interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                             Open         High          Low        Close  \
# Datetime
# 2022-12-21 00:00:00  1217.586426  1217.586426  1217.586426  1217.586426
# 2022-12-21 00:01:00  1217.319458  1217.319458  1217.319458  1217.319458
# 2022-12-21 00:02:00  1217.234131  1217.234131  1217.234131  1217.234131
# 2022-12-21 00:03:00  1217.251831  1217.251831  1217.251831  1217.251831
# 2022-12-21 00:04:00  1217.346069  1217.346069  1217.346069  1217.346069
# ...                          ...          ...          ...          ...
# 2022-12-21 23:54:00  1212.758423  1212.758423  1212.758423  1212.758423
# 2022-12-21 23:55:00  1212.607056  1212.607056  1212.607056  1212.607056
# 2022-12-21 23:56:00  1212.667236  1212.667236  1212.667236  1212.667236
# 2022-12-21 23:57:00  1213.098022  1213.098022  1213.098022  1213.098022
# 2022-12-21 23:58:00  1213.545532  1213.545532  1213.545532  1213.545532
#
#                        Adj Close   Volume
# Datetime
# 2022-12-21 00:00:00  1217.586426        0
# 2022-12-21 00:01:00  1217.319458        0
# 2022-12-21 00:02:00  1217.234131        0
# 2022-12-21 00:03:00  1217.251831        0
# 2022-12-21 00:04:00  1217.346069        0
# ...                          ...      ...
# 2022-12-21 23:54:00  1212.758423        0
# 2022-12-21 23:55:00  1212.607056        0
# 2022-12-21 23:56:00  1212.667236        0
# 2022-12-21 23:57:00  1213.098022  1226496
# 2022-12-21 23:58:00  1213.545532  2409984
#
# [1432 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]
mu_1 = 0.02
mu_2 = 0.03
sigma_1 = 0.04
sigma_2 = 0.8
rho = 0.5
z_0 = 0.00
beta = 1
gamma = 0.3
delta = 0.8
T = 1
M = 1432

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = S1[t-1] * np.exp((mu_1 + delta * z[t] - sigma_1 ** 2 / 2) * dt + sigma_1 * np.sqrt(dt) * rn1[t])
    S2[t] = S2[t-1] * np.exp((mu_2 - sigma_2 ** 2 / 2) * dt + sigma_2 * np.sqrt(dt) * (rho * rn1[t] + np.sqrt(1 - rho ** 2) * rn2[t]))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Bitcoin')
plt.plot(tt, S2, 'r', lw=1.5, label='Ethereum')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Crypto Price')
# Out:
# Text(0.5, 1.0, 'Crypto Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([707.620669])

# %%
Wealth[-1]
# Out:
# array([23.80654983])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([-0.9663569])

# %%
Pi_1.mean()
# Out:
# 0.008816367588744795

# %%
Pi_2.mean()
# Out:
# 0.10097177548732929

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')
